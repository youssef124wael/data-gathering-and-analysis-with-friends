# %%
import pandas as pd

# %%
df = pd.read_csv("courses.csv")
df.head(3)
# Out:
#    Unnamed: 0                                              title rating  \
# 0           0     Google Data Analytics Professional Certificate    4.8
# 1           1      Google Cybersecurity Professional Certificate    4.8
# 2           2  Google Project Management: Professional Certif...    4.8
#
#                                      completion_time   modules_number
# 0  Earn a career credential that demonstrates you...  8 course series
# 1  Earn a career credential that demonstrates you...  8 course series
# 2  Earn a career credential that demonstrates you...  6 course series

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       995 non-null    int64
#  1   title            995 non-null    object
#  2   rating           995 non-null    object
#  3   completion_time  995 non-null    object
#  4   modules_number   995 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 23.4+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0
# count   995.00000
# mean    497.00000
# std     287.37606
# min       0.00000
# 25%     248.50000
# 50%     497.00000
# 75%     745.50000
# max     994.00000

# %%
df['rating'] = pd.to_numeric(df['rating'], errors='coerce') # ==> I got that from stackflow

# %%
df # ==> df = df.drop("Unnamed: 0", axis = 1, inplace=True)
# Out:
#                                                  title  rating  \
# 0       Google Data Analytics Professional Certificate     4.8
# 1        Google Cybersecurity Professional Certificate     4.8
# 2    Google Project Management: Professional Certif...     4.8
# 3    Google Digital Marketing & E-commerce Professi...     4.8
# 4           Google IT Support Professional Certificate     4.8
# ..                                                 ...     ...
# 990  Positive Psychology: Applications and Interven...     4.8
# 991     Microsoft PL-300 Exam Preparation and Practice     4.6
# 992                           Data Science Math Skills     4.5
# 993            Introduction to HTML, CSS, & JavaScript     4.5
# 994  Information Systems Auditing, Controls and Ass...     4.7
#
#                                        completion_time   modules_number
# 0    Earn a career credential that demonstrates you...  8 course series
# ...

# %%
df.loc[df.duplicated()] # ==> Some stupid python, we're sorry
# Out:
#                                                  title  rating  \
# 500     Google Data Analytics Professional Certificate     4.8
# 744     Google Data Analytics Professional Certificate     4.8
# 851  A Crash Course in Causality:  Inferring Causal...     4.7
# 875                              Machine Design Part I     4.8
# 881                     Introduction to Data Analytics     4.8
# 889      Google Cybersecurity Professional Certificate     4.8
# 901  Google Project Management: Professional Certif...     4.8
# 906          Google UX Design Professional Certificate     4.8
# 947  International Law in Action: A Guide to the In...     4.8
# 948                    Rust Programming Specialization     4.0
# 983            Google Advanced Data Analytics Capstone     4.9
# 984  Hotel Management: Distribution, Revenue and De...     4.7
#
#                                        completion_time   modules_number
# 500  Earn a career credential that demonstrates you...  8 course series
# ...

# %%
df.isnull().sum()
# Out:
# title               0
# rating             13
# completion_time     0
# modules_number      0
# dtype: int64

# %%
df.loc[df['rating'].isnull()]
# Out:
#                                                  title  rating  \
# 249  Renew your CBRS Professional Installer certifi...     NaN
# 389  Developing Mobile Apps with React Native Speci...     NaN
# 502  Business Analyst (ECBA) Certificate Preparatio...     NaN
# 528            Introduction to 3D Printing with Metals     NaN
# 601                      Sustainable Corporate Finance     NaN
# 648                     GPU Programming Specialization     NaN
# 712  Product Owner Certification [PSPO I] Preparati...     NaN
# 837                DevOps and AI on AWS Specialization     NaN
# 871  Certified Associate in Project Management (CAP...     NaN
# 915     AI Agents: From Prompts to Multi-Agent Systems     NaN
# 938                 WordPress 101 - The Complete Guide     NaN
# 959  Mastering Program Management: Strategy to Cert...     NaN
# 968                 Superar el estrÃ©s rompiendo mitos     NaN
#
#                                        completion_time   modules_number
# ...

# %% [markdown]
# ## `Quality`:
# - `Consistency issue`: rating should be ==float instead of object(text) => Done 🗿
# - unnecessary column 'Unnamed: 0' => Done 👍
# - `Completeness issue`: None values
# - `Validity issue`: No issues (insha`Allah 🗿)
# - `Accuracy issue`: No issues (insha`Allah 🗿)
# ## `Tidiness`:
# - So tidy (Masha`Allah 🗿)
