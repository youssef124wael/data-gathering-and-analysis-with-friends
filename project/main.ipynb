# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('courses.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                              title rating  \
# 0           0     Google Data Analytics Professional Certificate    4.8
# 1           1      Google Cybersecurity Professional Certificate    4.8
# 2           2  Google Project Management: Professional Certif...    4.8
# 3           3  Google Digital Marketing & E-commerce Professi...    4.8
# 4           4         Google IT Support Professional Certificate    4.8
#
#                                      completion_time   modules_number
# 0  Earn a career credential that demonstrates you...  8 course series
# 1  Earn a career credential that demonstrates you...  8 course series
# 2  Earn a career credential that demonstrates you...  6 course series
# 3  Earn a career credential that demonstrates you...  7 course series
# 4  Earn a career credential that demonstrates you...  5 course series

# %%
df.drop(columns='Unnamed: 0',inplace=True)

# %%
df.head()
# Out:
#                                                title rating  \
# 0     Google Data Analytics Professional Certificate    4.8
# 1      Google Cybersecurity Professional Certificate    4.8
# 2  Google Project Management: Professional Certif...    4.8
# 3  Google Digital Marketing & E-commerce Professi...    4.8
# 4         Google IT Support Professional Certificate    4.8
#
#                                      completion_time   modules_number
# 0  Earn a career credential that demonstrates you...  8 course series
# 1  Earn a career credential that demonstrates you...  8 course series
# 2  Earn a career credential that demonstrates you...  6 course series
# 3  Earn a career credential that demonstrates you...  7 course series
# 4  Earn a career credential that demonstrates you...  5 course series

# %%
def determining_type(df):
    list_of_amount = df.split(' ')
    return list_of_amount[1]
df['type'] = df['modules_number'].apply(determining_type)

# %%
df
# Out:
#                                                  title rating  \
# 0       Google Data Analytics Professional Certificate    4.8
# 1        Google Cybersecurity Professional Certificate    4.8
# 2    Google Project Management: Professional Certif...    4.8
# 3    Google Digital Marketing & E-commerce Professi...    4.8
# 4           Google IT Support Professional Certificate    4.8
# ..                                                 ...    ...
# 990  Positive Psychology: Applications and Interven...    4.8
# 991     Microsoft PL-300 Exam Preparation and Practice    4.6
# 992                           Data Science Math Skills    4.5
# 993            Introduction to HTML, CSS, & JavaScript    4.5
# 994  Information Systems Auditing, Controls and Ass...    4.7
#
#                                        completion_time   modules_number  \
# 0    Earn a career credential that demonstrates you...  8 course series
# 1    Earn a career credential that demonstrates you...  8 course series
# ...
